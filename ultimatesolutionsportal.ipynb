# %%
# !wget -N https://chromedriver.storage.googleapis.com/100.0.4896.60/chromedriver_linux64.zip -P /tmp/
# !unzip -o /tmp/chromedriver_linux64.zip -d /tmp/
# !chmod +x /tmp/chromedriver
# !mv /tmp/chromedriver /usr/local/bin/chromedriver
# !pip install selenium
# !apt-get update
# !wget https://mirror.cs.uchicago.edu/google-chrome/pool/main/g/google-chrome-stable/google-chrome-stable_100.0.4896.60-1_amd64.deb
# !sudo apt-get install -f ./google-chrome-stable_100.0.4896.60-1_amd64.deb

# !sudo ln -s /opt/google/chrome-unstable/google-chrome google-chrome-stable!
# !pip install --upgrade yt-dlp
# Out:
# --2024-07-17 16:23:33--  https://chromedriver.storage.googleapis.com/100.0.4896.60/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 142.251.184.207, 209.85.200.207, 74.125.126.207, ...
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|142.251.184.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6986125 (6.7M) [application/zip]
# Saving to: ‘/tmp/chromedriver_linux64.zip’
#
# chromedriver_linux6 100%[===================>]   6.66M  --.-KB/s    in 0.09s
#
# 2024-07-17 16:23:33 (74.0 MB/s) - ‘/tmp/chromedriver_linux64.zip’ saved [6986125/6986125]
#
# Archive:  /tmp/chromedriver_linux64.zip
#   inflating: /tmp/chromedriver
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.7/475.7 kB 22.5 MB/s eta 0:00:00
# ...

# %%
url ="https://minds.ultimatesolutionsportal.com/courses/restaurant-management-system-ferp/lessons/sales-setting-transactions/"

from selenium import webdriver
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
URL = "https://google.com"

options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument('--disable-dev-shm-usage')
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(
    options=options
)


driver.get("https://minds.ultimatesolutionsportal.com/account/")
title = driver.title
print(title)
#wait = WebDriverWait(driver, 1)
#wait.until(EC.element_to_be_clickable((By.XPATH,'//*[@id="login-popup-3"]/div/div/a[2]'))).click()
username = driver.find_element("name", "log")
username.send_keys('faris4y@yemensoft.net')

password = driver.find_element("name", "pwd")
password.send_keys('73836903')

driver.find_element("name", "wp-submit").click()
#WebDriverWait(driver, 70).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "login"))).click()

driver.get(url)
list_links = driver.find_elements("xpath","//a")

links = []
for i in list_links:
  link = i.get_attribute('href')
  if link.startswith('https://minds.ultimatesolutionsportal.com/courses') and not link.endswith("#") and not link.endswith("#respond") and not (link == 'https://minds.ultimatesolutionsportal.com/courses/') and link not in links:
    links.append(link)

iframes = []
for i in links[1:]:
  driver.get(i)
  iframe = driver.find_element("xpath","//iframe")
  iframes.append(iframe.get_attribute("src"))
# Out:
# Account – Ultimate Minds

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import os.path
from os import path
if path.exists('ultimatesolutionsportal') == False:
  os.mkdir('ultimatesolutionsportal')
os.chdir("/content/drive/MyDrive/ultimatesolutionsportal/")
# !cd /content/drive/MyDrive/ultimatesolutionsportal

from pathlib import Path
from urllib.parse import urlparse, urlunparse

yt_urls = []
def convert_to_watch_url(embed_url: str) -> str:
    """Convert a YouTube embed URL into a watch URL."""

    scheme, netloc, path, params, query, fragment = urlparse(embed_url)
    video_id, path = Path(path).stem, '/watch'
    return urlunparse((scheme, netloc, path, params, f'v={video_id}', fragment))

for embed_url in iframes:
  yt_urls.append(convert_to_watch_url(embed_url))

for ind,url in enumerate(yt_urls):
  # !yt-dlp $url
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=S-wD5b7UQ7A
# [youtube] S-wD5b7UQ7A: Downloading webpage
# [youtube] S-wD5b7UQ7A: Downloading ios player API JSON
# [youtube] S-wD5b7UQ7A: Downloading player 8eff86d5
# [youtube] S-wD5b7UQ7A: Downloading m3u8 information
# [info] S-wD5b7UQ7A: Downloading 1 format(s): 137+251
# [download] Destination: FERP session 1 6 2021 اعدادات و عمليات المبيعات [S-wD5b7UQ7A].f137.mp4
# [download] 100% of  133.45MiB in 00:00:23 at 5.69MiB/s
# [download] Destination: FERP session 1 6 2021 اعدادات و عمليات المبيعات [S-wD5b7UQ7A].f251.webm
# [download] 100% of   58.74MiB in 00:00:11 at 5.26MiB/s
# [Merger] Merging formats into "FERP session 1 6 2021 اعدادات و عمليات المبيعات [S-wD5b7UQ7A].mkv"
# Deleting original file FERP session 1 6 2021 اعدادات و عمليات المبيعات [S-wD5b7UQ7A].f137.mp4 (pass -k to keep)
# Deleting original file FERP session 1 6 2021 اعدادات و عمليات المبيعات [S-wD5b7UQ7A].f251.webm (pass -k to keep)
# ...

# %%
# !cd /content/drive/MyDrive/ultimatesolutionsportal
# !yt-dlp https://www.youtube.com/watch?v=8_RIWM39isM
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8_RIWM39isM
# [youtube] 8_RIWM39isM: Downloading webpage
# [youtube] 8_RIWM39isM: Downloading ios player API JSON
# [youtube] 8_RIWM39isM: Downloading m3u8 information
# [info] 8_RIWM39isM: Downloading 1 format(s): 137+251
# [download] Onyx Restaurant Apps 20240523 110638 Meeting Recording [8_RIWM39isM].mkv has already been downloaded

# %%
# !apt -y install ffmpeg lame
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# Suggested packages:
#   lame-doc
# The following NEW packages will be installed:
#   lame
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 51.3 kB of archives.
# After this operation, 129 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lame amd64 3.100-3build2 [51.3 kB]
# Fetched 51.3 kB in 0s (270 kB/s)
# Selecting previously unselected package lame.
# (Reading database ... 123589 files and directories currently installed.)
# Preparing to unpack .../lame_3.100-3build2_amd64.deb ...
# Unpacking lame (3.100-3build2) ...
# Setting up lame (3.100-3build2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !cd /content/drive/MyDrive/ultimatesolutionsportal
# !yt-dlp https://www.youtube.com/watch?v=pjoxnEQWc-4
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pjoxnEQWc-4
# [youtube] pjoxnEQWc-4: Downloading webpage
# [youtube] pjoxnEQWc-4: Downloading ios player API JSON
# [youtube] pjoxnEQWc-4: Downloading m3u8 information
# [info] pjoxnEQWc-4: Downloading 1 format(s): 136+251
# [download] Destination: HMS   Session 3 [pjoxnEQWc-4].f136.mp4
# [download] 100% of  180.89MiB in 00:00:14 at 12.48MiB/s
# [download] Destination: HMS   Session 3 [pjoxnEQWc-4].f251.webm
# [download] 100% of  125.41MiB in 00:00:14 at 8.52MiB/s
# [Merger] Merging formats into "HMS   Session 3 [pjoxnEQWc-4].mkv"
# Deleting original file HMS   Session 3 [pjoxnEQWc-4].f251.webm (pass -k to keep)
# Deleting original file HMS   Session 3 [pjoxnEQWc-4].f136.mp4 (pass -k to keep)

# %%
# %cd /content/drive/MyDrive/ultimatesolutionsportal
# !ls
# Out:
# /content/drive/MyDrive/ultimatesolutionsportal
#  0.mp3
#  10.mp3
#  11.mp3
#  12.mp3
#  13.mp3
#  14.mp3
#  15.mp3
#  16.mp3
#  17.mp3
#  18.mp3
#  19.mp3
#  1.mp3
#  20.mp3
#  21.mp3
#  22.mp3
#  23.mp3
#  24.mp3
#  25.mp3
#  26.mp3
#  27.mp3
#  28.mp3
#  29.mp3
#  2.mp3
#  30.mp3
#  31.mp3
#  32.mp3
#  33.mp3
#  34.mp3
#  35.mp3
#  36.mp3
#  37.mp3
#  38.mp3
#  39.mp3
#  3.mp3
#  40.mp3
#  41.mp3
#  42.mp3
#  43.mp3
#  44.mp3
#  45.mp3
#  46.mp3
#  47.mp3
#  48.mp3
#  49.mp3
#  4.mp3
#  50.mp3
#  51.mp3
#  52.mp3
#  53.mp3
#  54.mp3
#  55.mp3
#  56.mp3
#  57.mp3
#  58.mp3
#  59.mp3
#  5.mp3
#  60.mp3
#  62.mp3
#  63.mp3
#  64.mp3
#  65.mp3
#  66.mp3
#  67.mp3
#  68.mp3
#  69.mp3
#  6.mp3
#  70.mp3
#  71.mp3
#  72.mp3
#  74.mp3
#  7.mp3
#  8.mp3
#  9.mp3
# 'FERP 3 6 2021 اعدادات و عمليات الحسابات [nCd0k6lJp3I].mkv'
# 'FERP session 1 6 2021 اعدادات و عمليات المبيعات [S-wD5b7UQ7A].mkv'
# 'FERP session 2 1 اعدادات و عمليات المخازن 2 6 2021 [ObSL6eLmiv8].mkv'
# ...

# %%
# !cd /content/drive/MyDrive/ultimatesolutionsportal
# !ffmpeg -i 'طلب تحويل و تحويل [4dQ8XkZjC5c].mkv' -vn -ab 128k -ar 44100 -y '73.mp3'
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
cd /content/drive/MyDrive/ultimatesolutionsportal
# Out:
# /content/drive/MyDrive

# %%
iframes = []
for i in links[1:]:
  driver.get(i)
  iframe = driver.find_element("xpath","//iframe")
  iframes.append(iframe.get_attribute("src"))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-49-820be9418c67> in <cell line: 2>()
#       2 for i in links[1:]:
#       3   driver.get(i)
# ----> 4   iframe = driver.find_element("xpath","//iframe")
#       5   iframes.append(iframe.get_attribute("src"))
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     746             value = f'[name="{value}"]'
#     747
# --> 748         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     749
#     750     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     352         response = self.command_executor.execute(driver_command, params)
# ...

# %%
iframes = []
for i in links[1:]:
  driver.get(i)
  try:
    iframe = driver.find_element("xpath","//iframe")
    iframes.append(iframe.get_attribute("src"))
  except:
    pass

# %%
print(len(iframes))
# Out:
# 8
